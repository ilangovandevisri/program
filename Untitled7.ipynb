# %% [markdown]
# <a href="https://colab.research.google.com/github/ilangovandevisri/program/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nested_list = [[1, 2, 3], [4, 5], [6, 7, 8]]

total = 0

for sublist in nested_list:
    for num in sublist:
        total = total + num

print("Sum =", total)
# Out:
# Sum = 36

# %%
a = "hello"
b = "hello"

print(a == b)
print(a is b)
# Out:
# True
# True

# %%
arr = [10, 20, 30, 20, 40]
x = 20

index = -1

for i in range(len(arr)):
    if arr[i] == x:
        index = i
        break

print("First occurrence index:", index)
# Out:
# First occurrence index: 1

# %%
arr = list(map(int, input("Enter array elements: ").split()))
x = int(input("Enter element to find: "))

index = -1

for i in range(len(arr)):
    if arr[i] == x:
        index = i

print(index)
# Out:
# Enter array elements: 1 2 5 4 8
# Enter element to find: 5
# 2
